# %%
import  pandas as  pd
df = pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
missing = (df.isnull().sum()/len(df))*100
missing.sort_values(ascending=False)
# Out:
# director        29.908028
# country          9.435676
# cast             9.367549
# date_added       0.113546
# rating           0.045418
# duration         0.034064
# show_id          0.000000
# type             0.000000
# title            0.000000
# release_year     0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
# now data profiing

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['country'].nunique()
# Out:
# 748

# %%
df['listed_in'].nunique()
# Out:
# 514

# %%
df['listed_in'].value_counts()
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
#                                                    ...
# Action & Adventure, Cult Movies                       1
# Action & Adventure, Comedies, Music & Musicals        1
# Classic Movies, Horror Movies, Thrillers              1
# Children & Family Movies, Classic Movies, Dramas      1
# Cult Movies, Dramas, Thrillers                        1
# Name: count, Length: 514, dtype: int64

# %%
df['rating'].nunique()
# Out:
# 17

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# data cleaning

# %%
print(df['date_added'].dtype)
# Out:
# object

# %%
df['date_added']
# Out:
# 0       September 25, 2021
# 1       September 24, 2021
# 2       September 24, 2021
# 3       September 24, 2021
# 4       September 24, 2021
#                ...
# 8802     November 20, 2019
# 8803          July 1, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 8807, dtype: object

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7716/2944776423.py in <cell line: 0>()
# ----> 1 df['date_added'] = pd.to_datetime(df['date_added'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# ...

# %%
df['date_added'].iloc[1442]
# Out:
# 'January 4, 2021'

# %%
print(repr(df['date_added'].iloc[1442]))
# Out:
# 'January 4, 2021'

# %%
df['date_added'] = df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7716/3238958532.py in <cell line: 0>()
# ----> 1 df['date_added'] = df['date_added'].str.strip()
#       2 df['date_added'] = pd.to_datetime(df['date_added'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df['date_added'] = pd.to_datetime(
    df['date_added'].astype(str).str.strip(),
    errors='coerce'
)

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
# data cleaning

df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# feature eng

# %%
df['year_added'] = df['date_added'].dt.year

# %%
df['month_added'] = df['date_added'].dt.month_name()

# %%
df['day_added'] = df['date_added'].dt.day_name()

# %%
df[['date_added','year_added','month_added']].head()
# Out:
#   date_added  year_added month_added
# 0 2021-09-25      2021.0   September
# 1 2021-09-24      2021.0   September
# 2 2021-09-24      2021.0   September
# 3 2021-09-24      2021.0   September
# 4 2021-09-24      2021.0   September

# %%
total_content  = len(df)
total_content
# Out:
# 8807

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
movies = df[df['type']=='Movie'].shape[0]

movies
# Out:
# 6131

# %%
tv_shows = df[df['type']=='tv_shows'].shape[0]

movies
# Out:
# 6131

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['country'].nunique()
# Out:
# 748

# %%
df['rating'].mode()[0]
# Out:
# 'TV-MA'

# %%
df['listed_in'].mode()
# Out:
# 0    Dramas, International Movies
# Name: listed_in, dtype: object

# %%
# now  some bussiness insights
import plotly.express as px

# %%
import plotly.express as px

fig = px.pie(
    df,
    names='type',
    title='Movies vs TV Shows'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
country  = df['country'].value_counts().head(10)
country
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
fig = px.bar(
     x = country.index,
     y = country.values,
     title = 'Top 10 Countries'

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
yearly = (
    df['release_year']
    .value_counts()

)
yearly
fig = px.line(
    x=yearly.index,
    y=yearly.values,
    title='Netflix Content Growth'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ratings = df['rating'].value_counts().head(10)
ratings

fig = px.bar(
     x = ratings.index,
     y = ratings.values,
     title = 'Top 10 Ratings'

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# statistics

# %%
df['release_year'].mean()
(df['release_year'] == 2014).sum()
df[df['release_year'] == 2014]['type'].value_counts()
# Out:
# type
# Movie      264
# TV Show     88
# Name: count, dtype: int64

# %%
df['release_year'].median()
# Out:
# 2017.0

# %%
df['release_year'].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
df['release_year'].var()
# Out:
# 77.78026646107675

# %%
df['release_year'].std()
# Out:
# 8.819312130834057

# %%
# cross tab

# %%
pd.crosstab(
    df['type'],
    df['rating']
)
# Out:
# rating   66 min  74 min  84 min   G  NC-17  NR   PG  PG-13    R  TV-14  TV-G  \
# type
# Movie         1       1       1  41      3  75  287    490  797   1427   126
# TV Show       0       0       0   0      0   5    0      0    2    733    94
#
# rating   TV-MA  TV-PG  TV-Y  TV-Y7  TV-Y7-FV  UR
# type
# Movie     2062    540   131    139         5   3
# TV Show   1145    323   176    195         1   0

# %%
pd.crosstab(
    df['country'],
    df['type']
)
# Out:
# type                                                Movie  TV Show
# country
# , France, Algeria                                       1        0
# , South Korea                                           0        1
# Argentina                                              38       18
# Argentina, Brazil, France, Poland, Germany, Den...      1        0
# Argentina, Chile                                        2        0
# ...                                                   ...      ...
# Venezuela                                               1        0
# Venezuela, Colombia                                     1        0
# Vietnam                                                 7        0
# West Germany                                            1        0
# Zimbabwe                                                1        0
#
# [748 rows x 2 columns]

# %%
# pivot table analysis

# %%
pd.pivot_table(
    df,
    index='type',
    values='show_id',
    aggfunc='count'
)
# Out:
#          show_id
# type
# Movie       6131
# TV Show     2676

# %%
pd.pivot_table(
    df,
    index='rating',
    values='release_year',
    aggfunc='mean'

)
# Out:
#           release_year
# rating
# 66 min     2015.000000
# 74 min     2017.000000
# 84 min     2010.000000
# G          1997.804878
# NC-17      2015.000000
# NR         2010.912500
# PG         2008.428571
# PG-13      2009.314286
# R          2010.471840
# TV-14      2013.655556
# TV-G       2015.745455
# TV-MA      2016.661678
# TV-PG      2013.529548
# TV-Y       2017.159609
# TV-Y7      2015.508982
# TV-Y7-FV   2014.833333
# UR         1999.333333

# %%
pd.pivot_table(
    df,
    index='rating',
    values='release_year',
    aggfunc=['mean' , 'max'  , 'min']
)
# Out:
#                  mean          max          min
#          release_year release_year release_year
# rating
# 66 min    2015.000000         2015         2015
# 74 min    2017.000000         2017         2017
# 84 min    2010.000000         2010         2010
# G         1997.804878         2020         1956
# NC-17     2015.000000         2018         2013
# NR        2010.912500         2018         1958
# PG        2008.428571         2021         1973
# PG-13     2009.314286         2021         1955
# R         2010.471840         2021         1962
# TV-14     2013.655556         2021         1925
# TV-G      2015.745455         2021         1954
# TV-MA     2016.661678         2021         1945
# TV-PG     2013.529548         2021         1943
# TV-Y      2017.159609         2021         1992
# TV-Y7     2015.508982         2021         1981
# TV-Y7-FV  2014.833333         2018         2012
# UR        1999.333333         2016         1974

# %%
# grop by analysis

# %%
df.groupby('year_added')['show_id'].count()
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      24
# 2015.0      82
# 2016.0     429
# 2017.0    1188
# 2018.0    1649
# 2019.0    2016
# 2020.0    1879
# 2021.0    1498
# Name: show_id, dtype: int64

# %%
df.groupby('type')['show_id'].count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: show_id, dtype: int64

# %%
df.groupby('type')['release_year'].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
top_dir = df['director'].value_counts().head(10)

fig = px.bar(
    x=top_dir.values,
    y=top_dir.index,
    orientation='h',
    title='Top Directors'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 📌 Executive Summary

## Key Findings:-

# - Netflix catalog contains 6,131 Movies and 2,676 TV Shows.
# - Movies account for nearly 70% of total content.
# - United States contributes the highest number of titles.
# - India ranks second in content production.
# - Netflix experienced rapid growth after 2016.
# - TV-MA is the most common content rating.
# - Drama-based content dominates the platform.

# %%
# ## Final Conclusion

# Netflix has evolved into a global streaming platform with a strong movie-focused catalog, significant international content investments, and rapid content expansion after 2016. The platform's strategy appears to focus on globally appealing, mature, and drama-oriented content.
